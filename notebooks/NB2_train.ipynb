# %% [markdown]
# # NB2_train
# 실행 전에 아래 코드 셀의 `REPO_URL`을 조교의 fork 주소로 반드시 먼저 설정하세요 (기본값은 자리표시자입니다). `camsim/config.yaml`을 수정한 뒤 아래 셀을 순서대로 실행하세요.

# %%
REPO_URL = "https://github.com/<YOUR-FORK>/f1tenth_gym.git"   # ← 조교의 fork 주소로 바꾸세요
BRANCH = "camsim"
# !git clone --branch $BRANCH $REPO_URL 2>/dev/null || true
# %cd f1tenth_gym
# !pip install -q -r camsim/requirements.txt
# !bash camsim/scripts/install_gym019.sh
# !pip install -q --no-build-isolation -e .
# numpy가 다운그레이드되면 '런타임 다시 시작' 후 이 셀부터 다시 실행

# %%
# !cat camsim/config.yaml

# %%
# %run camsim/scripts/nb2_train.py 3000 32 cuda

# %%
import torch; print('gpu', torch.cuda.is_available())
